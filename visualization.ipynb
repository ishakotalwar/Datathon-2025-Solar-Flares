# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Number of solar flares by class
# Load cleaned data
df = pd.read_csv("solar_flare_data_cleaned.csv")

# Count the number of flares in each class
class_counts = df['flare_class_peak'].value_counts().sort_index()

# Plot bar chart
plt.figure(figsize=(6, 4))
sns.barplot(x=class_counts.index, y=class_counts.values)

# Add labels and title
plt.title('Number of Solar Flares by Class')
plt.xlabel('Flare Class (A, B, C, M, X)')
plt.ylabel('Count')
plt.tight_layout()
plt.show()


# Load cleaned data
df = pd.read_csv("solar_flare_data_cleaned.csv")

# Set desired class order
flare_class_order = ['A', 'B', 'C', 'M', 'X']


# xrsb_flux vs. flare_class

plt.figure(figsize=(8, 5))
sns.boxplot(x='flare_class_peak', y='xrsb_flux', data=df, order=flare_class_order)

# Customize plot
plt.title('Xrsb Flux by Flare Class at Peak')
plt.xlabel('Flare Class (Peak)')
plt.ylabel('Xrsb Flux')
plt.yscale('log')  # Apply log scale to better visualize wide flux ranges

# Show plot
plt.tight_layout()
plt.show()

# background_flux vs. flare_class

plt.figure(figsize=(8, 5))
sns.boxplot(x='flare_class_peak', y='background_flux', data=df, order=flare_class_order)

# Customize plot
plt.title('Background Flux by Flare Class at Peak')
plt.xlabel('Flare Class (Peak)')
plt.ylabel('Background Flux')
plt.yscale('log')

# Show plot
plt.tight_layout()
plt.show()

# integrated_flux vs. flare_class

plt.figure(figsize=(8, 5))
sns.boxplot(x='flare_class_peak', y='integrated_flux', data=df, order=flare_class_order)

# Customize plot
plt.title('Integrated Flux by Flare Class at Peak')
plt.xlabel('Flare Class (Peak)')
plt.ylabel('Integrated Flux')
plt.yscale('log')

# Show plot
plt.tight_layout()
plt.show()

# %%
_dntk.DeepnoteChart(df, """{"layer":[{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","color":"#2266D3","tooltip":true},"encoding":{"x":{"sort":null,"type":"nominal","field":"flare_class_peak","scale":{"type":"linear"}},"y":{"axis":{"format":{"type":"default","decimals":null},"formatType":"numberFormatFromNumberType"},"type":"quantitative","field":"xrsb_flux","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"color":{"type":"nominal","datum":"xrsb_flux","scale":{"range":["#2266D3"],"domain":["xrsb_flux"]}},"xOffset":{"datum":"series_0"}},"transform":[]}]}],"resolve":{"scale":{"color":"independent"}}}],"title":"","config":{"legend":{"disable":false}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{},"usermeta":{"seriesNames":["xrsb_flux"],"seriesOrder":[0],"specSchemaVersion":2,"tooltipDefaultMode":true}}""")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=059000a2-e207-4dc7-9f7e-f909ccf665aa' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
